# %% [markdown]
# # **Extraction à partir d'un fichier Excel**

# %%
import pandas as pd

# Charger le fichier Excel et lire la deuxième feuille
path = "/content/drive/MyDrive/Sample_Superstore.xlsx"
df = pd.read_excel(path)
df.head()
# Out:
#     Region  Manager
# 0  Central    Chris
# 1     East     Erin
# 2    South      Sam
# 3     West  William

# %%
# Lire le fichier avec index_col défini sur "Row ID"
df2 = pd.read_excel(path, sheet_name=1)
df2.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington  Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington  Anacortes        98221 2011-07-27 2011-07-27
#
#      Profit  Quantity ordered new    Sales Order ID
# 0    1.3200                     2     5.90    88525
# 1    4.5600                     4    13.01    88522
# 2  -47.6400                     7    49.92    88523
# 3  -30.5100                     7    41.64    88523
# 4  998.2023                     8  1446.67    88523
#
# [5 rows x 24 columns]

# %%
df2_idx = pd.read_excel(path, sheet_name=1, index_col='Row ID')
df2_idx.head()
df2_idx['Customer Name']
# Out:
# Row ID
# 18606    Janice Fletcher
# 20847      Bonnie Potter
# 23086      Bonnie Potter
# 23087      Bonnie Potter
# 23088      Bonnie Potter
#               ...
# 20275     Frederick Cole
# 20276     Frederick Cole
# 24491     Frederick Cole
# 25914      Tammy Buckley
# 24492      Tammy Buckley
# Name: Customer Name, Length: 9426, dtype: object

# %% [markdown]
# # **Manipulation de données à partie d'un fichier CSV**

# %%
import pandas as pd

# Charger le fichier CSV dans un DataFrame
path = '/content/drive/MyDrive/catdata.csv'
catdata = pd.read_csv(path, sep=';')
catdata.head()
# Out:
#   haircolor hairpattern     sex  weight  age foodtype
# 0       red    tortoise  female     3.7    7      dry
# 1     black      tipped    male     6.0    4      wet
# 2     black       tabby    male     5.4    4      dry
# 3     white       solid    male     5.0    4      dry
# 4     brown      tipped  female     3.3    6      dry

# %%
catdata.index
# Out:
# RangeIndex(start=0, stop=153, step=1)

# %%
catdata.columns
# Out:
# Index(['haircolor', 'hairpattern', 'sex', 'weight', 'age', 'foodtype'], dtype='object')

# %% [markdown]
# # **Anlayse Statistique univarié**

# %%
catdata.age.describe()
# Out:
# count    153.000000
# mean       6.333333
# std        2.752989
# min        2.000000
# 25%        4.000000
# 50%        6.000000
# 75%        8.000000
# max       14.000000
# Name: age, dtype: float64

# %%
print(f"Moyenne d'age: {catdata.age.mean()}")
# Out:
# Moyenne d'age: 6.333333333333333

# %%
catdata.age.value_counts()
# Out:
# age
# 5     25
# 4     24
# 6     23
# 7     19
# 8     15
# 3     14
# 10     8
# 9      8
# 2      5
# 14     4
# 13     4
# 11     3
# 12     1
# Name: count, dtype: int64

# %%
catdata.age.sort_values()
# Out:
# 48      2
# 135     2
# 25      2
# 13      2
# 106     2
#        ..
# 32     13
# 133    14
# 53     14
# 21     14
# 78     14
# Name: age, Length: 153, dtype: int64

# %%
catdata.hairpattern.unique()
# Out:
# array(['tortoise', 'tipped', 'tabby', 'solid', 'colorpoint'], dtype=object)

# %%
catdata.loc[catdata.hairpattern == 'solid']
# Out:
#     haircolor hairpattern     sex  weight  age foodtype
# 3       white       solid    male     5.0    4      dry
# 9       black       solid  female     4.0    4      dry
# 11      black       solid  female     4.9    8      wet
# 13      black       solid  female     6.1    2      dry
# 27      black       solid    male     5.4   13      dry
# 33      white       solid    male     5.2    6      dry
# 35        red       solid  female     4.5    7      dry
# 37      white       solid    male     3.7    8      wet
# 42      black       solid  female     4.1    6    other
# 46      brown       solid  female     5.1    5      wet
# 54      black       solid  female     5.3    5      dry
# 57        red       solid  female     4.3   10      dry
# 61        red       solid    male     4.9    4      dry
# 68      white       solid    male     5.3    6      dry
# 81      black       solid    male     5.0    4      wet
# 82      black       solid    male     5.3    7      dry
# 83      black       solid    male     5.7    8      dry
# 107     black       solid    male     5.4    4    other
# 108     black       solid    male     4.6    9      wet
# 113     black       solid    male     5.6    5      dry
# 118     brown       solid    male     4.7    5      dry
# 125       red       solid    male     4.9    9    other
# 129     black       solid  female     3.5    4      dry
# 132       red       solid    male     4.7    3      dry
# 133     black       solid  female     3.0   14      dry
# 134     black       solid    male     5.0    6      dry
# 135     brown       solid    male     5.9    2      dry
# 140     black       solid    male     6.0    3      dry
# 141       red       solid    male     4.8    9      wet
# 146     brown       solid    male     4.2    5      dry
# 149     white       solid  female     4.5    5      dry

# %%
print(f"Nombre des observations True: {catdata.hairpattern.loc[catdata.hairpattern == 'solid'].count()}")
print(f"Nombre des observations False: {catdata.hairpattern.loc[catdata.hairpattern != 'solid'].count()}")
# Out:
# Nombre des observations True: 31
# Nombre des observations False: 122

# %%
catdata.loc[catdata.hairpattern.isin(['solid', 'tabby'])]
# Out:
#     haircolor hairpattern     sex  weight  age foodtype
# 2       black       tabby    male     5.4    4      dry
# 3       white       solid    male     5.0    4      dry
# 8       black       tabby    male     5.2    8      dry
# 9       black       solid  female     4.0    4      dry
# 11      black       solid  female     4.9    8      wet
# ..        ...         ...     ...     ...  ...      ...
# 147     white       tabby  female     4.3    4      dry
# 149     white       solid  female     4.5    5      dry
# 150     black       tabby  female     6.0    4      wet
# 151     white       tabby  female     5.3    8      dry
# 152     black       tabby  female     5.8   10      dry
#
# [89 rows x 6 columns]

# %%
catdata.loc[(catdata.hairpattern == 'solid' ) & (catdata.sex =='female')]
# Out:
#     haircolor hairpattern     sex  weight  age foodtype
# 9       black       solid  female     4.0    4      dry
# 11      black       solid  female     4.9    8      wet
# 13      black       solid  female     6.1    2      dry
# 35        red       solid  female     4.5    7      dry
# 42      black       solid  female     4.1    6    other
# 46      brown       solid  female     5.1    5      wet
# 54      black       solid  female     5.3    5      dry
# 57        red       solid  female     4.3   10      dry
# 129     black       solid  female     3.5    4      dry
# 133     black       solid  female     3.0   14      dry
# 149     white       solid  female     4.5    5      dry

# %% [markdown]
# ## **Croisement des Variables**

# %%
crosstab = pd.crosstab(catdata.sex, catdata.hairpattern)
crosstab.head()
# Out:
# hairpattern  colorpoint  solid  tabby  tipped  tortoise
# sex
# female                9     11     27      13         8
# male                  5     20     31      14        15

# %%
crosstab = pd.crosstab(catdata.sex, catdata.hairpattern, normalize='index')
crosstab.head()
# Out:
# hairpattern  colorpoint     solid     tabby    tipped  tortoise
# sex
# female         0.132353  0.161765  0.397059  0.191176  0.117647
# male           0.058824  0.235294  0.364706  0.164706  0.176471

# %%
crosstab = pd.crosstab(catdata.sex, catdata.hairpattern, normalize='columns')
crosstab.head()
# Out:
# hairpattern  colorpoint     solid     tabby    tipped  tortoise
# sex
# female         0.642857  0.354839  0.465517  0.481481  0.347826
# male           0.357143  0.645161  0.534483  0.518519  0.652174

# %% [markdown]
# # **Construction de variables calculées **

# %%
weightPound = catdata.weight.apply(lambda x: x *  2.20462)
weightPound
# Out:
# 0       8.157094
# 1      13.227720
# 2      11.904948
# 3      11.023100
# 4       7.275246
#          ...
# 148     8.157094
# 149     9.920790
# 150    13.227720
# 151    11.684486
# 152    12.786796
# Name: weight, Length: 153, dtype: float64

# %%
import numpy as np
weightLog = catdata.weight.apply(lambda x: np.log(x))
weightLog.head()
# Out:
# 0    1.308333
# 1    1.791759
# 2    1.686399
# 3    1.609438
# 4    1.193922
# Name: weight, dtype: float64

# %% [markdown]
# # **Concaténation **

# %%
catnew = pd.concat([catdata, weightPound, weightLog], axis=1)
catnew.head()
# Out:
#   haircolor hairpattern     sex  weight  age foodtype     weight    weight
# 0       red    tortoise  female     3.7    7      dry   8.157094  1.308333
# 1     black      tipped    male     6.0    4      wet  13.227720  1.791759
# 2     black       tabby    male     5.4    4      dry  11.904948  1.686399
# 3     white       solid    male     5.0    4      dry  11.023100  1.609438
# 4     brown      tipped  female     3.3    6      dry   7.275246  1.193922

# %%
catnew.columns = ['haircolor',
 'hairpattern',
 'sex',
 'weight',
 'age',
 'foodtype',
 'weightPound',
 'weightLog']

catnew.head()
# Out:
#   haircolor hairpattern     sex  weight  age foodtype  weightPound  weightLog
# 0       red    tortoise  female     3.7    7      dry     8.157094   1.308333
# 1     black      tipped    male     6.0    4      wet    13.227720   1.791759
# 2     black       tabby    male     5.4    4      dry    11.904948   1.686399
# 3     white       solid    male     5.0    4      dry    11.023100   1.609438
# 4     brown      tipped  female     3.3    6      dry     7.275246   1.193922

# %% [markdown]
# # **Ajouter /Remplir/Supprimer des colonnes /lignes et modification des valeur**

# %%
path = '/content/drive/MyDrive/earthquake.csv'
data =pd.read_csv(path)
data.head()
# Out:
#   alert  cdi      code                                             detail  \
# 0   NaN  NaN  37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN  37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4  37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN  37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN  73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap           ids   mag magType  ...  sources     status  \
# 0  0.008693   NaN   85.0  ,ci37389218,  1.35      ml  ...     ,ci,  automatic
# 1  0.020030   NaN   79.0  ,ci37389202,  1.29      ml  ...     ,ci,  automatic
# 2  0.021370  28.0   21.0  ,ci37389194,  3.42      ml  ...     ,ci,  automatic
# 3  0.026180   NaN   39.0  ,ci37389186,  0.44      ml  ...     ,ci,  automatic
# 4  0.077990   NaN  192.0  ,nc73096941,  2.16      md  ...     ,nc,  automatic
#
#             time                          title  tsunami        type  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA        0  earthquake
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA        0  earthquake
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA        0  earthquake
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA        0  earthquake
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA        0  earthquake
#
#                                                types     tz        updated  \
# 0         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475395144
# 1         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475253925
# 2  ,dyfi,focal-mechanism,geoserve,nearby-cities,o... -480.0  1539536756176
# 3         ,geoserve,nearby-cities,origin,phase-data, -480.0  1539475196167
# 4  ,geoserve,nearby-cities,origin,phase-data,scit... -480.0  1539477547926
#
#                                                  url
# 0  https://earthquake.usgs.gov/earthquakes/eventp...
# 1  https://earthquake.usgs.gov/earthquakes/eventp...
# 2  https://earthquake.usgs.gov/earthquakes/eventp...
# 3  https://earthquake.usgs.gov/earthquakes/eventp...
# 4  https://earthquake.usgs.gov/earthquakes/eventp...
#
# [5 rows x 26 columns]

# %%
data = data[['time', 'title', 'place', 'magType', 'mag', 'alert',
'tsunami']]
data.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami
# 0      ml  1.35   NaN        0
# 1      ml  1.29   NaN        0
# 2      ml  3.42   NaN        0
# 3      ml  0.44   NaN        0
# 4      md  2.16   NaN        0

# %%
source = pd.Series(['USGS API' for i in range(len(data))], name='source')
data = pd.concat([data, source], axis=1)
data.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami    source
# 0      ml  1.35   NaN        0  USGS API
# 1      ml  1.29   NaN        0  USGS API
# 2      ml  3.42   NaN        0  USGS API
# 3      ml  0.44   NaN        0  USGS API
# 4      md  2.16   NaN        0  USGS API

# %%
data['mag_negative'] = data.mag <0
data.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami    source  mag_negative
# 0      ml  1.35   NaN        0  USGS API         False
# 1      ml  1.29   NaN        0  USGS API         False
# 2      ml  3.42   NaN        0  USGS API         False
# 3      ml  0.44   NaN        0  USGS API         False
# 4      md  2.16   NaN        0  USGS API         False

# %%
data.place.unique()
# Out:
# array(['9km NE of Aguanga, CA', '8km NE of Aguanga, CA',
#        '10km NW of Avenal, CA', ..., '9km ENE of Mammoth Lakes, CA',
#        '3km W of Julian, CA', '35km NNE of Hatillo, Puerto Rico'],
#       dtype=object)

# %%
data['parsed_place'] = data.place.str.replace(r'CA', 'California').str.replace(r'NV', 'Nevada').str.replace(r'MX', 'Mexico')
data.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami    source  mag_negative  \
# 0      ml  1.35   NaN        0  USGS API         False
# 1      ml  1.29   NaN        0  USGS API         False
# 2      ml  3.42   NaN        0  USGS API         False
# 3      ml  0.44   NaN        0  USGS API         False
# 4      md  2.16   NaN        0  USGS API         False
#
#                     parsed_place
# 0  9km NE of Aguanga, California
# 1  9km NE of Aguanga, California
# 2  8km NE of Aguanga, California
# 3  9km NE of Aguanga, California
# 4  10km NW of Avenal, California

# %%
data[["parsed_place", "place"]].to_excel('parsed_place.xlsx', index=True)
data = data.assign(
    in_CA=data["parsed_place"].str.contains("California", na=False),
    in_AL=data["parsed_place"].str.contains("Alaska", na=False)
)

data[["parsed_place", "in_CA", "in_AL"]].head()
# Out:
#                     parsed_place  in_CA  in_AL
# 0  9km NE of Aguanga, California   True  False
# 1  9km NE of Aguanga, California   True  False
# 2  8km NE of Aguanga, California   True  False
# 3  9km NE of Aguanga, California   True  False
# 4  10km NW of Avenal, California   True  False

# %%
copy = data.copy()
copy.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami    source  mag_negative  \
# 0      ml  1.35   NaN        0  USGS API         False
# 1      ml  1.29   NaN        0  USGS API         False
# 2      ml  3.42   NaN        0  USGS API         False
# 3      ml  0.44   NaN        0  USGS API         False
# 4      md  2.16   NaN        0  USGS API         False
#
#                     parsed_place  in_CA  in_AL
# 0  9km NE of Aguanga, California   True  False
# 1  9km NE of Aguanga, California   True  False
# 2  8km NE of Aguanga, California   True  False
# 3  9km NE of Aguanga, California   True  False
# 4  10km NW of Avenal, California   True  False

# %%
copy.loc[copy.parsed_place == '9km NE of Aguanga, California', 'parsed_place'] = 'California'
copy.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami    source  mag_negative  \
# 0      ml  1.35   NaN        0  USGS API         False
# 1      ml  1.29   NaN        0  USGS API         False
# 2      ml  3.42   NaN        0  USGS API         False
# 3      ml  0.44   NaN        0  USGS API         False
# 4      md  2.16   NaN        0  USGS API         False
#
#                     parsed_place  in_CA  in_AL
# 0                     California   True  False
# 1                     California   True  False
# 2  8km NE of Aguanga, California   True  False
# 3                     California   True  False
# 4  10km NW of Avenal, California   True  False

# %%
copy.iloc[2, 9] = 'California'
copy.head()
# Out:
#             time                          title                  place  \
# 0  1539475168010  M 1.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 1  1539475129610  M 1.3 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 2  1539475062610  M 3.4 - 8km NE of Aguanga, CA  8km NE of Aguanga, CA
# 3  1539474978070  M 0.4 - 9km NE of Aguanga, CA  9km NE of Aguanga, CA
# 4  1539474716050  M 2.2 - 10km NW of Avenal, CA  10km NW of Avenal, CA
#
#   magType   mag alert  tsunami    source  mag_negative  \
# 0      ml  1.35   NaN        0  USGS API         False
# 1      ml  1.29   NaN        0  USGS API         False
# 2      ml  3.42   NaN        0  USGS API         False
# 3      ml  0.44   NaN        0  USGS API         False
# 4      md  2.16   NaN        0  USGS API         False
#
#                     parsed_place  in_CA  in_AL
# 0                     California   True  False
# 1                     California   True  False
# 2                     California   True  False
# 3                     California   True  False
# 4  10km NW of Avenal, California   True  False

# %%
del copy['time']
copy.columns
# Out:
# Index(['title', 'place', 'magType', 'mag', 'alert', 'tsunami', 'source',
#        'mag_negative', 'parsed_place', 'in_CA', 'in_AL'],
#       dtype='object')

# %%
copy.drop([2, 3], inplace=True)
copy.head()
# Out:
#                                                title magType   mag  tsunami  \
# 0                      M 1.4 - 9km NE of Aguanga, CA      ml  1.35        0
# 1                      M 1.3 - 9km NE of Aguanga, CA      ml  1.29        0
# 4                      M 2.2 - 10km NW of Avenal, CA      md  2.16        0
# 5  M 2.6 - 55km ESE of Punta Cana, Dominican Repu...      md  2.61        0
# 6               M 1.7 - 105km W of Talkeetna, Alaska      ml  1.70        0
#
#      source  mag_negative                                parsed_place  in_CA  \
# 0  USGS API         False                                  California   True
# 1  USGS API         False                                  California   True
# 4  USGS API         False               10km NW of Avenal, California   True
# 5  USGS API         False  55km ESE of Punta Cana, Dominican Republic  False
# 6  USGS API         False                105km W of Talkeetna, Alaska  False
#
#    in_AL
# 0  False
# 1  False
# 4  False
# 5  False
# 6   True

# %% [markdown]
# # **Traitement des données dupliquées, manquantes ou invalides**

# %%
path = '/content/drive/MyDrive/olympic_data.csv'
olympic = pd.read_csv(path)
olympic.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
olympic.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
olympic_notna = olympic[olympic.Age.notna()]
olympic_notna.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age            0
# Height     51574
# Weight     54263
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     222591
# dtype: int64

# %%
olympic.isna().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height         0
# Weight         0
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
olympic.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 271111    False
# 271112    False
# 271113    False
# 271114    False
# 271115    False
# Length: 271116, dtype: bool

# %%
olympic.duplicated().sum()
olympic.drop_duplicates(inplace=True)
olympic.duplicated().sum()
olympic["Year"] = pd.to_datetime(olympic.Year, format="%Y")
olympic_sorted = olympic.sort_index(axis=1)
olympic_sorted.head()
# Out:
#     Age       City                             Event        Games  Height  ID  \
# 0  24.0  Barcelona       Basketball Men's Basketball  1992 Summer   180.0   1
# 1  23.0     London      Judo Men's Extra-Lightweight  2012 Summer   170.0   2
# 2  24.0  Antwerpen           Football Men's Football  1920 Summer     0.0   3
# 3  34.0      Paris       Tug-Of-War Men's Tug-Of-War  1900 Summer     0.0   4
# 4  21.0    Calgary  Speed Skating Women's 500 metres  1988 Winter   185.0   5
#
#   Medal  NOC                      Name  Season Sex          Sport  \
# 0   NaN  CHN                 A Dijiang  Summer   M     Basketball
# 1   NaN  CHN                  A Lamusi  Summer   M           Judo
# 2   NaN  DEN       Gunnar Nielsen Aaby  Summer   M       Football
# 3  Gold  DEN      Edgar Lindenau Aabye  Summer   M     Tug-Of-War
# 4   NaN  NED  Christine Jacoba Aaftink  Winter   F  Speed Skating
#
#              Team     Weight       Year
# 0           China  80.000000 1992-01-01
# 1           China  60.000000 2012-01-01
# 2         Denmark  70.702393 1920-01-01
# 3  Denmark/Sweden  70.702393 1900-01-01
# 4     Netherlands  82.000000 1988-01-01

# %%
sorted_weight = olympic.sort_values(by='Weight', na_position="last")
sorted_weight.head()
# Out:
#           ID            Name Sex   Age  Height  Weight         Team  NOC  \
# 40849  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40850  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40851  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40852  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
# 40853  21049  Choi Myong-Hui   F  14.0   135.0    25.0  North Korea  PRK
#
#              Games       Year  Season    City       Sport  \
# 40849  1980 Summer 1980-01-01  Summer  Moskva  Gymnastics
# 40850  1980 Summer 1980-01-01  Summer  Moskva  Gymnastics
# 40851  1980 Summer 1980-01-01  Summer  Moskva  Gymnastics
# 40852  1980 Summer 1980-01-01  Summer  Moskva  Gymnastics
# 40853  1980 Summer 1980-01-01  Summer  Moskva  Gymnastics
#
#                                           Event Medal
# 40849  Gymnastics Women's Individual All-Around   NaN
# 40850        Gymnastics Women's Team All-Around   NaN
# 40851         Gymnastics Women's Floor Exercise   NaN
# 40852            Gymnastics Women's Horse Vault   NaN
# 40853            Gymnastics Women's Uneven Bars   NaN

# %%
sorted_weight = olympic.sort_values(by='Weight', na_position="last", ascending=False)

# %% [markdown]
# # **Manipulation avancée des données avec Pandas**

# %%
olympic.head()
# Out:
#    ID                      Name Sex   Age  Height     Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0  80.000000           China
# 1   2                  A Lamusi   M  23.0   170.0  60.000000           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     0.0  70.702393         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     0.0  70.702393  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0  82.000000     Netherlands
#
#    NOC        Games       Year  Season       City          Sport  \
# 0  CHN  1992 Summer 1992-01-01  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer 2012-01-01  Summer     London           Judo
# 2  DEN  1920 Summer 1920-01-01  Summer  Antwerpen       Football
# 3  DEN  1900 Summer 1900-01-01  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter 1988-01-01  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %%
group_sex = olympic.groupby('Sex', as_index=False)
group_sex.head()
# Out:
#     ID                      Name Sex   Age  Height     Weight            Team  \
# 0    1                 A Dijiang   M  24.0   180.0  80.000000           China
# 1    2                  A Lamusi   M  23.0   170.0  60.000000           China
# 2    3       Gunnar Nielsen Aaby   M  24.0     0.0  70.702393         Denmark
# 3    4      Edgar Lindenau Aabye   M  34.0     0.0  70.702393  Denmark/Sweden
# 4    5  Christine Jacoba Aaftink   F  21.0   185.0  82.000000     Netherlands
# 5    5  Christine Jacoba Aaftink   F  21.0   185.0  82.000000     Netherlands
# 6    5  Christine Jacoba Aaftink   F  25.0   185.0  82.000000     Netherlands
# 7    5  Christine Jacoba Aaftink   F  25.0   185.0  82.000000     Netherlands
# 8    5  Christine Jacoba Aaftink   F  27.0   185.0  82.000000     Netherlands
# 10   6           Per Knut Aaland   M  31.0   188.0  75.000000   United States
#
#     NOC        Games       Year  Season         City                 Sport  \
# 0   CHN  1992 Summer 1992-01-01  Summer    Barcelona            Basketball
# 1   CHN  2012 Summer 2012-01-01  Summer       London                  Judo
# 2   DEN  1920 Summer 1920-01-01  Summer    Antwerpen              Football
# 3   DEN  1900 Summer 1900-01-01  Summer        Paris            Tug-Of-War
# 4   NED  1988 Winter 1988-01-01  Winter      Calgary         Speed Skating
# 5   NED  1988 Winter 1988-01-01  Winter      Calgary         Speed Skating
# 6   NED  1992 Winter 1992-01-01  Winter  Albertville         Speed Skating
# 7   NED  1992 Winter 1992-01-01  Winter  Albertville         Speed Skating
# 8   NED  1994 Winter 1994-01-01  Winter  Lillehammer         Speed Skating
# 10  USA  1992 Winter 1992-01-01  Winter  Albertville  Cross Country Skiing
#
#                                        Event Medal
# 0                Basketball Men's Basketball   NaN
# 1               Judo Men's Extra-Lightweight   NaN
# 2                    Football Men's Football   NaN
# 3                Tug-Of-War Men's Tug-Of-War  Gold
# 4           Speed Skating Women's 500 metres   NaN
# 5         Speed Skating Women's 1,000 metres   NaN
# 6           Speed Skating Women's 500 metres   NaN
# 7         Speed Skating Women's 1,000 metres   NaN
# 8           Speed Skating Women's 500 metres   NaN
# 10  Cross Country Skiing Men's 10 kilometres   NaN

# %%
group_age_team = olympic.groupby(['Age', 'Team'])
group_age_team.head()
# Out:
#             ID                                       Name Sex   Age  Height  \
# 0            1                                  A Dijiang   M  24.0   180.0
# 1            2                                   A Lamusi   M  23.0   170.0
# 2            3                        Gunnar Nielsen Aaby   M  24.0     0.0
# 3            4                       Edgar Lindenau Aabye   M  34.0     0.0
# 4            5                   Christine Jacoba Aaftink   F  21.0   185.0
# ...        ...                                        ...  ..   ...     ...
# 270610  135343                 Aleksandr Yuryevich Zubkov   M  39.0   189.0
# 270681  135370                              Franco Zucchi   M  42.0   172.0
# 270971  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  43.0   183.0
# 270972  135501  Ellina Aleksandrovna Zvereva (Kisheyeva-)   F  47.0   183.0
# 271111  135569                                 Andrzej ya   M  29.0   179.0
#
#             Weight            Team  NOC        Games       Year  Season  \
# 0        80.000000           China  CHN  1992 Summer 1992-01-01  Summer
# 1        60.000000           China  CHN  2012 Summer 2012-01-01  Summer
# 2        70.702393         Denmark  DEN  1920 Summer 1920-01-01  Summer
# 3        70.702393  Denmark/Sweden  DEN  1900 Summer 1900-01-01  Summer
# 4        82.000000     Netherlands  NED  1988 Winter 1988-01-01  Winter
# ...            ...             ...  ...          ...        ...     ...
# 270610  102.000000        Russia-1  RUS  2014 Winter 2014-01-01  Winter
# 270681   73.000000      Voloira II  ITA  1960 Summer 1960-01-01  Summer
# 270971  100.000000         Belarus  BLR  2004 Summer 2004-01-01  Summer
# 270972  100.000000         Belarus  BLR  2008 Summer 2008-01-01  Summer
# 271111   89.000000        Poland-1  POL  1976 Winter 1976-01-01  Winter
#
#              City          Sport                             Event Medal
# 0       Barcelona     Basketball       Basketball Men's Basketball   NaN
# 1          London           Judo      Judo Men's Extra-Lightweight   NaN
# 2       Antwerpen       Football           Football Men's Football   NaN
# 3           Paris     Tug-Of-War       Tug-Of-War Men's Tug-Of-War  Gold
# 4         Calgary  Speed Skating  Speed Skating Women's 500 metres   NaN
# ...           ...            ...                               ...   ...
# 270610      Sochi      Bobsleigh              Bobsleigh Men's Four  Gold
# 270681       Roma        Sailing          Sailing Mixed 5.5 metres   NaN
# 270971     Athina      Athletics    Athletics Women's Discus Throw   NaN
# 270972    Beijing      Athletics    Athletics Women's Discus Throw   NaN
# 271111  Innsbruck           Luge        Luge Mixed (Men)'s Doubles   NaN
#
# [28341 rows x 15 columns]

# %%
pivot = olympic.pivot_table(index='Sport', columns='Year', values="Weight", aggfunc="mean")
pivot.head()
# Out:
# Year              1896-01-01  1900-01-01  1904-01-01  1906-01-01  1908-01-01  \
# Sport
# Aeronautics              NaN         NaN         NaN         NaN         NaN
# Alpine Skiing            NaN         NaN         NaN         NaN         NaN
# Alpinism                 NaN         NaN         NaN         NaN         NaN
# Archery                  NaN   70.702393   70.702393         NaN   70.702393
# Art Competitions         NaN         NaN         NaN         NaN         NaN
#
# Year              1912-01-01  1920-01-01  1924-01-01  1928-01-01  1932-01-01  \
# Sport
# Aeronautics              NaN         NaN         NaN         NaN         NaN
# Alpine Skiing            NaN         NaN         NaN         NaN         NaN
# Alpinism                 NaN         NaN   70.702393         NaN   70.702393
# Archery                  NaN   70.702393         NaN         NaN         NaN
# Art Competitions   70.702393   70.702393   70.782368   70.816573   70.783479
#
# Year              ...  1998-01-01  2000-01-01  2002-01-01  2004-01-01  \
# Sport             ...
# Aeronautics       ...         NaN         NaN         NaN         NaN
# Alpine Skiing     ...    74.68596         NaN    75.85101         NaN
# Alpinism          ...         NaN         NaN         NaN         NaN
# Archery           ...         NaN   70.157305         NaN   70.391509
# Art Competitions  ...         NaN         NaN         NaN         NaN
#
# Year              2006-01-01  2008-01-01  2010-01-01  2012-01-01  2014-01-01  \
# Sport
# Aeronautics              NaN         NaN         NaN         NaN         NaN
# Alpine Skiing      75.623933         NaN   75.307751         NaN   74.646116
# Alpinism                 NaN         NaN         NaN         NaN         NaN
# Archery                  NaN   72.673724         NaN      71.795         NaN
# Art Competitions         NaN         NaN         NaN         NaN         NaN
#
# Year              2016-01-01
# Sport
# Aeronautics              NaN
# Alpine Skiing            NaN
# Alpinism                 NaN
# Archery            72.217024
# Art Competitions         NaN
#
# [5 rows x 35 columns]
